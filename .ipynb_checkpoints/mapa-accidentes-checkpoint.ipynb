# %% [markdown]
# # Accidentes en tráfico en Zaragoza
#
# ¿Qué vamos a hacer?
#
#  * obtener los datos
#  * transformar el campo coordenadas
#  * construir un tabla con motivo del accidente, latitud y longitud
#
# ## Origen de datos
#
#
# https://www.zaragoza.es/sede/servicio/catalogo/1500#API
#
# El delimitador es el **;**
# Tiene dos parámetros, rows y start

# %%
import pandas as pd
import folium

# %%
url = 'https://www.zaragoza.es/sede/servicio/transporte/accidentalidad-trafico/accidente.csv?rows=100'

# %%
df = pd.read_csv(url,delimiter=';')

# %%
df
# Out:
#                                                    id  year  \
# 0   https://www.zaragoza.es/sede/servicio/transpor...  2014
# 1   https://www.zaragoza.es/sede/servicio/transpor...  2014
# 2   https://www.zaragoza.es/sede/servicio/transpor...  2014
# 3   https://www.zaragoza.es/sede/servicio/transpor...  2014
# 4   https://www.zaragoza.es/sede/servicio/transpor...  2014
# ..                                                ...   ...
# 95  https://www.zaragoza.es/sede/servicio/transpor...  2014
# 96  https://www.zaragoza.es/sede/servicio/transpor...  2014
# 97  https://www.zaragoza.es/sede/servicio/transpor...  2014
# 98  https://www.zaragoza.es/sede/servicio/transpor...  2014
# 99  https://www.zaragoza.es/sede/servicio/transpor...  2014
#
#                    type  accidentType                   firstAddress  \
# 0        SALIDA CALZADA           NaN                 COSTA, JOAQUIN
# 1      COLISIÓN ALCANCE           NaN          CADENA(MARQUES DE LA)
# 2      COLISIÓN ALCANCE           NaN           GOMEZ AVELLANEDA, G.
# 3   COLIS FRONTOLATERAL           NaN                         MONZON
# 4        SALIDA CALZADA           NaN                          RIOJA
# ..                  ...           ...                            ...
# 95                OTRAS           NaN                 MIRAL, DOMINGO
# 96     COLISIÓN ALCANCE           NaN  BUÑUEL,LUIS (PARQUE DEL AGUA)
# 97       SALIDA CALZADA           NaN              ALBAR, MANUEL GL.
# 98  COLIS FRONTOLATERAL           NaN          ECHEGARAY Y CABALLERO
# 99       SALIDA CALZADA           NaN            CESAR AUGUSTO, AVDA
#
#              secondAddress                                geometry  \
# 0             PERAL, ISAAC  -0.8818527060979306,41.649027473051156
# 1                      NaN  -0.8645810716721081,41.661585829868585
# 2       CASTRO, R. (POETA)   -0.887776415002892,41.666992622958105
# 3        GARCIA CONDOY, H.   -0.8825260453930127,41.62957498750602
# 4      NAVARRA, AVENIDA DE     -0.908314757720389,41.6562121210704
# ..                     ...                                     ...
# 95                     NaN   -0.8990662796872798,41.63977012001253
# 96                     NaN  -0.9072756956226459,41.670910841846876
# 97  ILUSTRACION, AV. DE LA   -0.9226018969034585,41.62757051008441
# 98        SAN VICENTE PAUL   -0.8735234620830842,41.65507219335992
# 99                     NaN   -0.8869504077778204,41.65022964156985
#
#                                           reason    area  \
# 0      PERDIDA del control por FALTA de ATENCIÓN     NaN
# 1            DISTANCIA DE SEGURIDAD, no mantener  2560.0
# 2      PERDIDA del control por FALTA de ATENCIÓN  2598.0
# 3    CEDA EL PASO, no respetar prioridad de paso  2555.0
# 4   PERDIDA del control por VELOCIDAD INADECUADA  2554.0
# ..                                           ...     ...
# 95     PERDIDA del control por FALTA de ATENCIÓN     NaN
# 96     PERDIDA del control por FALTA de ATENCIÓN  2071.0
# 97     PERDIDA del control por FALTA de ATENCIÓN  1969.0
# 98       SEMÁFORO, no respetar prioridad de paso  1970.0
# 99     PERDIDA del control por FALTA de ATENCIÓN  1971.0
#
#             creationDate  daniosMateriales  falloMecanico estadoPavimento  \
# 0   2014-10-09T00:00:00Z              True          False     BUEN ESTADO
# 1   2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 2   2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 3   2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 4   2014-10-24T00:00:00Z             False          False     BUEN ESTADO
# ..                   ...               ...            ...             ...
# 95  2014-07-30T00:00:00Z              True          False     BUEN ESTADO
# 96  2014-07-31T00:00:00Z              True          False     BUEN ESTADO
# 97  2014-07-25T00:00:00Z             False          False     BUEN ESTADO
# 98  2014-07-26T00:00:00Z             False          False     BUEN ESTADO
# 99  2014-07-09T00:00:00Z              True          False     BUEN ESTADO
#
#     tipoEstadoPavimento estadoAtmosfera  tipoEstadoAtmosfera  \
# 0                   NaN     BUEN ESTADO                  NaN
# 1                   NaN     BUEN ESTADO                  NaN
# 2                   NaN     BUEN ESTADO                  NaN
# 3                   NaN     BUEN ESTADO                  NaN
# 4                   NaN     BUEN ESTADO                  NaN
# ..                  ...             ...                  ...
# 95                  NaN     BUEN ESTADO                  NaN
# 96                  NaN     BUEN ESTADO                  NaN
# 97                  NaN     BUEN ESTADO                  NaN
# 98                  NaN     BUEN ESTADO                  NaN
# 99                  NaN     BUEN ESTADO                  NaN
#
#                                              afectado  \
# 0                                                 NaN
# 1   https://www.zaragoza.es/sede/servicio/transpor...
# 2   https://www.zaragoza.es/sede/servicio/transpor...
# 3   https://www.zaragoza.es/sede/servicio/transpor...
# 4   https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97  https://www.zaragoza.es/sede/servicio/transpor...
# 98  https://www.zaragoza.es/sede/servicio/transpor...
# 99                                                NaN
#
#                                              vehiculo
# 0   https://www.zaragoza.es/sede/servicio/transpor...
# 1   https://www.zaragoza.es/sede/servicio/transpor...
# 2   https://www.zaragoza.es/sede/servicio/transpor...
# 3   https://www.zaragoza.es/sede/servicio/transpor...
# 4   https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                ...
# 95  https://www.zaragoza.es/sede/servicio/transpor...
# 96  https://www.zaragoza.es/sede/servicio/transpor...
# 97  https://www.zaragoza.es/sede/servicio/transpor...
# 98  https://www.zaragoza.es/sede/servicio/transpor...
# 99  https://www.zaragoza.es/sede/servicio/transpor...
#
# [100 rows x 18 columns]

# %% [markdown]
# Aquí tenemos todos los datos pero mejor si lo evitamos, son 27000 accidentes y puede ir lento.

# %%
df = pd.read_csv('http://muimota.net/ojoaldato/accidentes.csv')
df
# Out:
#                                                       id  year  \
# 0      https://www.zaragoza.es/sede/servicio/transpor...  2014
# 1      https://www.zaragoza.es/sede/servicio/transpor...  2014
# 2      https://www.zaragoza.es/sede/servicio/transpor...  2014
# 3      https://www.zaragoza.es/sede/servicio/transpor...  2014
# 4      https://www.zaragoza.es/sede/servicio/transpor...  2014
# ...                                                  ...   ...
# 27495  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 27496  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 27497  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 27498  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 27499  https://www.zaragoza.es/sede/servicio/transpor...  2019
#
#                       type  accidentType             firstAddress  \
# 0           SALIDA CALZADA           NaN           COSTA, JOAQUIN
# 1         COLISIÓN ALCANCE           NaN    CADENA(MARQUES DE LA)
# 2         COLISIÓN ALCANCE           NaN     GOMEZ AVELLANEDA, G.
# 3      COLIS FRONTOLATERAL           NaN                   MONZON
# 4           SALIDA CALZADA           NaN                    RIOJA
# ...                    ...           ...                      ...
# 27495     COLISIÓN LATERAL           NaN            PLEYADES, LAS
# 27496     COLISIÓN LATERAL           NaN         UNIVERSITAS, VIA
# 27497     COLISIÓN LATERAL           NaN         CANOVAS, ANTONIO
# 27498       SALIDA CALZADA           NaN     LEGAZ LACAMBRA, LUIS
# 27499     COLISIÓN LATERAL           NaN  RODRIGUEZ AYUSO, MANUEL
#
#               secondAddress                                geometry  \
# 0              PERAL, ISAAC  -0.8818527060979306,41.649027473051156
# 1                       NaN  -0.8645810716721081,41.661585829868585
# 2        CASTRO, R. (POETA)   -0.887776415002892,41.666992622958105
# 3         GARCIA CONDOY, H.   -0.8825260453930127,41.62957498750602
# 4       NAVARRA, AVENIDA DE     -0.908314757720389,41.6562121210704
# ...                     ...                                     ...
# 27495                BOYERO   -0.9337782877014544,41.63888841722081
# 27496                   NaN  -0.9067375759951974,41.644789184898926
# 27497                   NaN   -0.8907497377774148,41.64811436227578
# 27498  GOMEZ AVELLANEDA, G.  -0.8908180267513072,41.676074625860785
# 27499                  BIEL  -0.9245669583272559,41.645615385662296
#
#                                                   reason    area  \
# 0              PERDIDA del control por FALTA de ATENCIÓN     NaN
# 1                    DISTANCIA DE SEGURIDAD, no mantener  2560.0
# 2              PERDIDA del control por FALTA de ATENCIÓN  2598.0
# 3            CEDA EL PASO, no respetar prioridad de paso  2555.0
# 4           PERDIDA del control por VELOCIDAD INADECUADA  2554.0
# ...                                                  ...     ...
# 27495          INCORPORARSE sin las debidas precauciones  2512.0
# 27496          INCORPORARSE sin las debidas precauciones  2513.0
# 27497  INVADIR otro carril en el mismo sentido de cir...  2707.0
# 27498          PERDIDA del control por FALTA de ATENCIÓN  2572.0
# 27499  INVADIR otro carril en el mismo sentido de cir...  2540.0
#
#                creationDate  daniosMateriales  falloMecanico estadoPavimento  \
# 0      2014-10-09T00:00:00Z              True          False     BUEN ESTADO
# 1      2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 2      2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 3      2014-10-23T00:00:00Z             False          False     BUEN ESTADO
# 4      2014-10-24T00:00:00Z             False          False     BUEN ESTADO
# ...                     ...               ...            ...             ...
# 27495  2019-09-20T00:00:00Z             False          False     BUEN ESTADO
# 27496  2019-09-18T00:00:00Z              True          False     BUEN ESTADO
# 27497  2019-09-21T00:00:00Z              True          False     BUEN ESTADO
# 27498  2019-09-22T00:00:00Z              True          False     BUEN ESTADO
# 27499  2019-09-20T00:00:00Z             False          False     BUEN ESTADO
#
#        tipoEstadoPavimento estadoAtmosfera  tipoEstadoAtmosfera  \
# 0                      NaN     BUEN ESTADO                  NaN
# 1                      NaN     BUEN ESTADO                  NaN
# 2                      NaN     BUEN ESTADO                  NaN
# 3                      NaN     BUEN ESTADO                  NaN
# 4                      NaN     BUEN ESTADO                  NaN
# ...                    ...             ...                  ...
# 27495                  NaN     BUEN ESTADO                  NaN
# 27496                  NaN     BUEN ESTADO                  NaN
# 27497                  NaN     BUEN ESTADO                  NaN
# 27498                  NaN     BUEN ESTADO                  NaN
# 27499                  NaN     BUEN ESTADO                  NaN
#
#                                                 afectado  \
# 0                                                    NaN
# 1      https://www.zaragoza.es/sede/servicio/transpor...
# 2      https://www.zaragoza.es/sede/servicio/transpor...
# 3      https://www.zaragoza.es/sede/servicio/transpor...
# 4      https://www.zaragoza.es/sede/servicio/transpor...
# ...                                                  ...
# 27495  https://www.zaragoza.es/sede/servicio/transpor...
# 27496                                                NaN
# 27497                                                NaN
# 27498                                                NaN
# 27499  https://www.zaragoza.es/sede/servicio/transpor...
#
#                                                 vehiculo
# 0      https://www.zaragoza.es/sede/servicio/transpor...
# 1      https://www.zaragoza.es/sede/servicio/transpor...
# 2      https://www.zaragoza.es/sede/servicio/transpor...
# 3      https://www.zaragoza.es/sede/servicio/transpor...
# 4      https://www.zaragoza.es/sede/servicio/transpor...
# ...                                                  ...
# 27495  https://www.zaragoza.es/sede/servicio/transpor...
# 27496  https://www.zaragoza.es/sede/servicio/transpor...
# 27497  https://www.zaragoza.es/sede/servicio/transpor...
# 27498  https://www.zaragoza.es/sede/servicio/transpor...
# 27499  https://www.zaragoza.es/sede/servicio/transpor...
#
# [27500 rows x 18 columns]

# %%
df['reason'].unique()
# Out:
# array(['PERDIDA del control por FALTA de ATENCIÓN',
#        'DISTANCIA DE SEGURIDAD, no mantener',
#        'CEDA EL PASO, no respetar prioridad de paso',
#        'PERDIDA del control por VELOCIDAD INADECUADA',
#        'Caída de ocupante en Transporte Público',
#        'PEATÓN cruza calz SIN PREFER. fuera de paso',
#        'INVADIR otro carril en el mismo sentido de circulación',
#        'PEATÓN cruza calz SIN PREFER. en PASO CON semáforo',
#        'PUERTA abierta incorrectamente', 'MARCHA ATRÁS',
#        'SEMÁFORO, no respetar prioridad de paso', 'OTRAS CAUSAS',
#        'PEATÓN cruza calz CON PREFER. en PASO  CON semáforo',
#        'PEATÓN cruza calz CON PREFER. en PASO  SIN semáforo',
#        'PEATÓN cruza calz CON PREFER. en PASO SIN semáforo',
#        'INCORPORARSE sin las debidas precauciones',
#        'GIROS: no respetar señal ó no ceñirse a la dirección',
#        'PEATÓN cruza calz CON PREFER. en PASO CON semáforo',
#        'Infracción Penal (con denuncia)',
#        'PEATÓN atropellado sobre la acera ó refugio',
#        'PEATÓN cruza calz SIN PREFER. en PASO  CON semáforo',
#        'STOP, no respetar prioridad de paso',
#        'SIN PODER DETERMINAR,  faltan datos',
#        'INVADIR otro carril en sentido contrario a la circulación',
#        'PREFERENCIA EN GLORIETA, no respetar',
#        'PEATÓN cruza calz CON PREFER. fuera de PASO (esquina)',
#        'DIRECCIÓN CONTRARIA, circular en',
#        'SIN PODER DETERMINAR, faltan datos',
#        'ESTACIONADO INCORRECTAMENTE',
#        'PREFERENCIA A LA  DERECHA, no respetar',
#        'PREFERENCIA A LA DERECHA, no respetar',
#        'ADELANTAMIENTO incorrecto', 'Daños propiedad', 'Otras causas',
#        'INCORPORARSE un BUS URBANO a la circulac. desde parada señaliz.',
#        'CAIDA DE PEATÓN EN AUTOBUS', 'Daños (Propiedad)', nan,
#        'INCORPORARSE sin las debidas precauciones)',
#        'PEATÓN cruza calz  fuera de PASO (esquina)',
#        'Infracción Penal (sin denuncia)'], dtype=object)

# %%
df = df.sample(200).reset_index(drop=True)
df
# Out:
#                                                     id  year  \
# 0    https://www.zaragoza.es/sede/servicio/transpor...  2019
# 1    https://www.zaragoza.es/sede/servicio/transpor...  2011
# 2    https://www.zaragoza.es/sede/servicio/transpor...  2016
# 3    https://www.zaragoza.es/sede/servicio/transpor...  2019
# 4    https://www.zaragoza.es/sede/servicio/transpor...  2013
# ..                                                 ...   ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...  2015
# 196  https://www.zaragoza.es/sede/servicio/transpor...  2011
# 197  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 198  https://www.zaragoza.es/sede/servicio/transpor...  2012
# 199  https://www.zaragoza.es/sede/servicio/transpor...  2012
#
#                     type  accidentType              firstAddress  \
# 0                  OTRAS           NaN    CARRETERA A BASE AEREA
# 1       COLISIÓN LATERAL           NaN       PUERTA DEL SOL (GL)
# 2                  OTRAS           NaN  FERIA DE MUESTRAS, RONDA
# 3         SALIDA CALZADA           NaN     PAMPLONA ESCUDERO, R.
# 4       COLISIÓN LATERAL           NaN           HISPANIDAD, VIA
# ..                   ...           ...                       ...
# 195     COLISIÓN ALCANCE           NaN              IBERICA, VIA
# 196     COLISIÓN LATERAL           NaN       ALMOZARA, AV. DE LA
# 197     COLISIÓN LATERAL           NaN        SEPTIMO ARTE,  AV.
# 198     COLISIÓN LATERAL           NaN       RUIZ PICASSO, PABLO
# 199  COLIS. MARCHA ATRÁS           NaN     PIGNATELLI, RAMON VIA
#
#              secondAddress                                geometry  \
# 0                      NaN   -1.0108306797183846,41.66794268058468
# 1    ECHEGARAY Y CABALLERO    -0.8718366106168601,41.6543864004582
# 2                      NaN   -0.9867478718241864,41.63868661503326
# 3                      NaN  -0.8954535877671523,41.645231667155365
# 4           NOBEL, ALFREDO   -0.9191809206635221,41.65128399988019
# ..                     ...                                     ...
# 195      BEARNE, GASTON DE   -0.9083015746698581,41.62804958985545
# 196                    NaN   -0.9018749844269355,41.66402028963055
# 197        CASABLANCA, AV.  -0.9267144844404782,41.620191328409014
# 198                    NaN   -0.8886578465095366,41.67319199839399
# 199                    NaN   -0.8894388683203909,41.63347811290818
#
#                                                 reason    area  \
# 0                                         OTRAS CAUSAS   890.0
# 1    INVADIR otro carril en el mismo sentido de cir...  1014.0
# 2                                         OTRAS CAUSAS   821.0
# 3            PERDIDA del control por FALTA de ATENCIÓN     NaN
# 4    GIROS: no respetar señal ó no ceñirse a la dir...   408.0
# ..                                                 ...     ...
# 195                DISTANCIA DE SEGURIDAD, no mantener    28.0
# 196          PERDIDA del control por FALTA de ATENCIÓN     NaN
# 197  INVADIR otro carril en el mismo sentido de cir...  2752.0
# 198          PERDIDA del control por FALTA de ATENCIÓN  2965.0
# 199                                       MARCHA ATRÁS  2931.0
#
#              creationDate  daniosMateriales  falloMecanico estadoPavimento  \
# 0    2019-03-23T00:00:00Z              True          False     BUEN ESTADO
# 1    2011-02-21T00:00:00Z              True          False     BUEN ESTADO
# 2    2016-03-18T00:00:00Z              True          False     BUEN ESTADO
# 3    2019-06-11T00:00:00Z              True          False     BUEN ESTADO
# 4    2013-02-02T00:00:00Z             False          False     BUEN ESTADO
# ..                    ...               ...            ...             ...
# 195  2015-01-04T00:00:00Z             False          False     BUEN ESTADO
# 196  2011-02-20T00:00:00Z              True          False     BUEN ESTADO
# 197  2019-10-10T00:00:00Z              True          False     BUEN ESTADO
# 198  2012-07-04T00:00:00Z              True          False     BUEN ESTADO
# 199  2012-06-28T00:00:00Z              True          False     BUEN ESTADO
#
#      tipoEstadoPavimento estadoAtmosfera  tipoEstadoAtmosfera  \
# 0                    NaN     BUEN ESTADO                  NaN
# 1                    NaN     BUEN ESTADO                  NaN
# 2                    NaN     BUEN ESTADO                  NaN
# 3                    NaN     BUEN ESTADO                  NaN
# 4                    NaN     BUEN ESTADO                  NaN
# ..                   ...             ...                  ...
# 195                  NaN     BUEN ESTADO                  NaN
# 196                  NaN     BUEN ESTADO                  NaN
# 197                  NaN     BUEN ESTADO                  NaN
# 198                  NaN     BUEN ESTADO                  NaN
# 199                  NaN     BUEN ESTADO                  NaN
#
#                                               afectado  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                 ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                                               vehiculo
# 0    https://www.zaragoza.es/sede/servicio/transpor...
# 1    https://www.zaragoza.es/sede/servicio/transpor...
# 2    https://www.zaragoza.es/sede/servicio/transpor...
# 3    https://www.zaragoza.es/sede/servicio/transpor...
# 4    https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                 ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...
# 196  https://www.zaragoza.es/sede/servicio/transpor...
# 197  https://www.zaragoza.es/sede/servicio/transpor...
# 198  https://www.zaragoza.es/sede/servicio/transpor...
# 199  https://www.zaragoza.es/sede/servicio/transpor...
#
# [200 rows x 18 columns]

# %% [markdown]
# # Coordenadas

# %%
df['geometry']
# Out:
# 0       -1.0108306797183846,41.66794268058468
# 1        -0.8718366106168601,41.6543864004582
# 2       -0.9867478718241864,41.63868661503326
# 3      -0.8954535877671523,41.645231667155365
# 4       -0.9191809206635221,41.65128399988019
#                         ...
# 195     -0.9083015746698581,41.62804958985545
# 196     -0.9018749844269355,41.66402028963055
# 197    -0.9267144844404782,41.620191328409014
# 198     -0.8886578465095366,41.67319199839399
# 199     -0.8894388683203909,41.63347811290818
# Name: geometry, Length: 200, dtype: object

# %% [markdown]
# ### Convertir una cadena a dos coordenadas

# %% [markdown]
# guardado en cadena, con esto no se puede hacer el mapa, tenemos que 'parsear' a latitud y longitud

# %%
df['geometry']
# Out:
# 0       -1.0108306797183846,41.66794268058468
# 1        -0.8718366106168601,41.6543864004582
# 2       -0.9867478718241864,41.63868661503326
# 3      -0.8954535877671523,41.645231667155365
# 4       -0.9191809206635221,41.65128399988019
#                         ...
# 195     -0.9083015746698581,41.62804958985545
# 196     -0.9018749844269355,41.66402028963055
# 197    -0.9267144844404782,41.620191328409014
# 198     -0.8886578465095366,41.67319199839399
# 199     -0.8894388683203909,41.63347811290818
# Name: geometry, Length: 200, dtype: object

# %%
df['geometry'][0]
# Out:
# '-1.0108306797183846,41.66794268058468'

# %%
df['geometry'][0].split(',')
# Out:
# ['-1.0108306797183846', '41.66794268058468']

# %%
'1' + '2'
# Out:
# '12'

# %%
float('12')
# Out:
# 12.0

# %%
pointStr = df['geometry'][0].split(',')

# %%
pointStr
# Out:
# ['-1.0108306797183846', '41.66794268058468']

# %%
pointStr[0]
# Out:
# '-1.0108306797183846'

# %%
float(pointStr[0])
# Out:
# -1.0108306797183846

# %%
[float(pointStr[0]),float(pointStr[1])]
# Out:
# [-1.0108306797183846, 41.66794268058468]

# %% [markdown]
# ## Longitud y Latitud
# Vamos a hacer dos listas una de longitudes y otra de latitudes
# Explicar:
#  * bucles
#  * añadir a lista

# %%
df['geometry']
# Out:
# 0       -1.0108306797183846,41.66794268058468
# 1        -0.8718366106168601,41.6543864004582
# 2       -0.9867478718241864,41.63868661503326
# 3      -0.8954535877671523,41.645231667155365
# 4       -0.9191809206635221,41.65128399988019
#                         ...
# 195     -0.9083015746698581,41.62804958985545
# 196     -0.9018749844269355,41.66402028963055
# 197    -0.9267144844404782,41.620191328409014
# 198     -0.8886578465095366,41.67319199839399
# 199     -0.8894388683203909,41.63347811290818
# Name: geometry, Length: 200, dtype: object

# %%
l = []
l = l + [1,2]
l = l + [3]
l
# Out:
# [1, 2, 3]

# %%
longitudes = []
for coordenadasStr in df['geometry']:
    pointStr = coordenadasStr.split(',')
    longitudes += [float(pointStr[0])]

# %%
latitudes = []
for coordenadasStr in df['geometry']:
    pointStr = coordenadasStr.split(',')
    latitudes += [float(pointStr[1])]

# %%
coordenadas = pd.DataFrame({'long':longitudes,'lat':latitudes})
coordenadas
# Out:
#          long        lat
# 0   -1.010831  41.667943
# 1   -0.871837  41.654386
# 2   -0.986748  41.638687
# 3   -0.895454  41.645232
# 4   -0.919181  41.651284
# ..        ...        ...
# 195 -0.908302  41.628050
# 196 -0.901875  41.664020
# 197 -0.926714  41.620191
# 198 -0.888658  41.673192
# 199 -0.889439  41.633478
#
# [200 rows x 2 columns]

# %%
df
# Out:
#                                                     id  year  \
# 0    https://www.zaragoza.es/sede/servicio/transpor...  2019
# 1    https://www.zaragoza.es/sede/servicio/transpor...  2011
# 2    https://www.zaragoza.es/sede/servicio/transpor...  2016
# 3    https://www.zaragoza.es/sede/servicio/transpor...  2019
# 4    https://www.zaragoza.es/sede/servicio/transpor...  2013
# ..                                                 ...   ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...  2015
# 196  https://www.zaragoza.es/sede/servicio/transpor...  2011
# 197  https://www.zaragoza.es/sede/servicio/transpor...  2019
# 198  https://www.zaragoza.es/sede/servicio/transpor...  2012
# 199  https://www.zaragoza.es/sede/servicio/transpor...  2012
#
#                     type  accidentType              firstAddress  \
# 0                  OTRAS           NaN    CARRETERA A BASE AEREA
# 1       COLISIÓN LATERAL           NaN       PUERTA DEL SOL (GL)
# 2                  OTRAS           NaN  FERIA DE MUESTRAS, RONDA
# 3         SALIDA CALZADA           NaN     PAMPLONA ESCUDERO, R.
# 4       COLISIÓN LATERAL           NaN           HISPANIDAD, VIA
# ..                   ...           ...                       ...
# 195     COLISIÓN ALCANCE           NaN              IBERICA, VIA
# 196     COLISIÓN LATERAL           NaN       ALMOZARA, AV. DE LA
# 197     COLISIÓN LATERAL           NaN        SEPTIMO ARTE,  AV.
# 198     COLISIÓN LATERAL           NaN       RUIZ PICASSO, PABLO
# 199  COLIS. MARCHA ATRÁS           NaN     PIGNATELLI, RAMON VIA
#
#              secondAddress                                geometry  \
# 0                      NaN   -1.0108306797183846,41.66794268058468
# 1    ECHEGARAY Y CABALLERO    -0.8718366106168601,41.6543864004582
# 2                      NaN   -0.9867478718241864,41.63868661503326
# 3                      NaN  -0.8954535877671523,41.645231667155365
# 4           NOBEL, ALFREDO   -0.9191809206635221,41.65128399988019
# ..                     ...                                     ...
# 195      BEARNE, GASTON DE   -0.9083015746698581,41.62804958985545
# 196                    NaN   -0.9018749844269355,41.66402028963055
# 197        CASABLANCA, AV.  -0.9267144844404782,41.620191328409014
# 198                    NaN   -0.8886578465095366,41.67319199839399
# 199                    NaN   -0.8894388683203909,41.63347811290818
#
#                                                 reason    area  \
# 0                                         OTRAS CAUSAS   890.0
# 1    INVADIR otro carril en el mismo sentido de cir...  1014.0
# 2                                         OTRAS CAUSAS   821.0
# 3            PERDIDA del control por FALTA de ATENCIÓN     NaN
# 4    GIROS: no respetar señal ó no ceñirse a la dir...   408.0
# ..                                                 ...     ...
# 195                DISTANCIA DE SEGURIDAD, no mantener    28.0
# 196          PERDIDA del control por FALTA de ATENCIÓN     NaN
# 197  INVADIR otro carril en el mismo sentido de cir...  2752.0
# 198          PERDIDA del control por FALTA de ATENCIÓN  2965.0
# 199                                       MARCHA ATRÁS  2931.0
#
#              creationDate  daniosMateriales  falloMecanico estadoPavimento  \
# 0    2019-03-23T00:00:00Z              True          False     BUEN ESTADO
# 1    2011-02-21T00:00:00Z              True          False     BUEN ESTADO
# 2    2016-03-18T00:00:00Z              True          False     BUEN ESTADO
# 3    2019-06-11T00:00:00Z              True          False     BUEN ESTADO
# 4    2013-02-02T00:00:00Z             False          False     BUEN ESTADO
# ..                    ...               ...            ...             ...
# 195  2015-01-04T00:00:00Z             False          False     BUEN ESTADO
# 196  2011-02-20T00:00:00Z              True          False     BUEN ESTADO
# 197  2019-10-10T00:00:00Z              True          False     BUEN ESTADO
# 198  2012-07-04T00:00:00Z              True          False     BUEN ESTADO
# 199  2012-06-28T00:00:00Z              True          False     BUEN ESTADO
#
#      tipoEstadoPavimento estadoAtmosfera  tipoEstadoAtmosfera  \
# 0                    NaN     BUEN ESTADO                  NaN
# 1                    NaN     BUEN ESTADO                  NaN
# 2                    NaN     BUEN ESTADO                  NaN
# 3                    NaN     BUEN ESTADO                  NaN
# 4                    NaN     BUEN ESTADO                  NaN
# ..                   ...             ...                  ...
# 195                  NaN     BUEN ESTADO                  NaN
# 196                  NaN     BUEN ESTADO                  NaN
# 197                  NaN     BUEN ESTADO                  NaN
# 198                  NaN     BUEN ESTADO                  NaN
# 199                  NaN     BUEN ESTADO                  NaN
#
#                                               afectado  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                 ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
#
#                                               vehiculo
# 0    https://www.zaragoza.es/sede/servicio/transpor...
# 1    https://www.zaragoza.es/sede/servicio/transpor...
# 2    https://www.zaragoza.es/sede/servicio/transpor...
# 3    https://www.zaragoza.es/sede/servicio/transpor...
# 4    https://www.zaragoza.es/sede/servicio/transpor...
# ..                                                 ...
# 195  https://www.zaragoza.es/sede/servicio/transpor...
# 196  https://www.zaragoza.es/sede/servicio/transpor...
# 197  https://www.zaragoza.es/sede/servicio/transpor...
# 198  https://www.zaragoza.es/sede/servicio/transpor...
# 199  https://www.zaragoza.es/sede/servicio/transpor...
#
# [200 rows x 18 columns]

# %%
latitudes[:10]
# Out:
# [41.66794268058468,
#  41.6543864004582,
#  41.63868661503326,
#  41.645231667155365,
#  41.65128399988019,
#  41.65357249364052,
#  41.63629649116116,
#  41.6459751025522,
#  41.6344615347489,
#  41.62345919951186]

# %% [markdown]
# En este punto tenemos dos listas, una con las longitudes, otra con las latitudes.
# Vamos a construir un DataFrame con estos datos
#  * vamos a usar el indice para poder relacionar, concatenar las tablas

# %%
pd.DataFrame({'col1':[1,2,3],'col2':[4,5,6]})
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %% [markdown]
# Creamos una tabla con el tipo longitud y latitud

# %%
df['type']
# Out:
# 0                    OTRAS
# 1         COLISIÓN LATERAL
# 2                    OTRAS
# 3           SALIDA CALZADA
# 4         COLISIÓN LATERAL
#               ...
# 195       COLISIÓN ALCANCE
# 196       COLISIÓN LATERAL
# 197       COLISIÓN LATERAL
# 198       COLISIÓN LATERAL
# 199    COLIS. MARCHA ATRÁS
# Name: type, Length: 200, dtype: object

# %%
accidentes = pd.concat([df['type'],coordenadas],axis=1)

# %%
accidentes
# Out:
#                     type      long        lat
# 0                  OTRAS -1.010831  41.667943
# 1       COLISIÓN LATERAL -0.871837  41.654386
# 2                  OTRAS -0.986748  41.638687
# 3         SALIDA CALZADA -0.895454  41.645232
# 4       COLISIÓN LATERAL -0.919181  41.651284
# ..                   ...       ...        ...
# 195     COLISIÓN ALCANCE -0.908302  41.628050
# 196     COLISIÓN LATERAL -0.901875  41.664020
# 197     COLISIÓN LATERAL -0.926714  41.620191
# 198     COLISIÓN LATERAL -0.888658  41.673192
# 199  COLIS. MARCHA ATRÁS -0.889439  41.633478
#
# [200 rows x 3 columns]

# %% [markdown]
# En este punto queremos 'concatenar' la tabla con el motivo y las coordenadas.
# De manera parecida a los graficos del otro día

# %%
accidentes
# Out:
#                     type      long        lat
# 0                  OTRAS -1.010831  41.667943
# 1       COLISIÓN LATERAL -0.871837  41.654386
# 2                  OTRAS -0.986748  41.638687
# 3         SALIDA CALZADA -0.895454  41.645232
# 4       COLISIÓN LATERAL -0.919181  41.651284
# ..                   ...       ...        ...
# 195     COLISIÓN ALCANCE -0.908302  41.628050
# 196     COLISIÓN LATERAL -0.901875  41.664020
# 197     COLISIÓN LATERAL -0.926714  41.620191
# 198     COLISIÓN LATERAL -0.888658  41.673192
# 199  COLIS. MARCHA ATRÁS -0.889439  41.633478
#
# [200 rows x 3 columns]

# %% [markdown]
# accidentes.assign(lat=latitudes)

# %% [markdown]
# accidentes

# %% [markdown]
# accidentes['long'] = longitudes

# %% [markdown]
# accidentes

# %% [markdown]
# # Crear el Mapa

# %%
mapa = folium.Map(location=[41.64,-0.88])

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bd6dc066e6d090392c51cb3c3fb701d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bd6dc066e6d090392c51cb3c3fb701d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bd6dc066e6d090392c51cb3c3fb701d = L.map(
#                 &quot;map_4bd6dc066e6d090392c51cb3c3fb701d&quot;,
#                 {
#                     center: [41.64, -0.88],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d35906137d47a8bcdd9f4a7ff05250b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d35906137d47a8bcdd9f4a7ff05250b.addTo(map_4bd6dc066e6d090392c51cb3c3fb701d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mapa = folium.Map(location=[41.64,-0.88])

# %%
marcador = folium.Marker([41.64,-0.88], popup="Zaragoza")

# %%
mapa = mapa.add_child(marcador)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9bd689b2a0a68a3d6992c57177e6c76c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9bd689b2a0a68a3d6992c57177e6c76c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9bd689b2a0a68a3d6992c57177e6c76c = L.map(
#                 &quot;map_9bd689b2a0a68a3d6992c57177e6c76c&quot;,
#                 {
#                     center: [41.64, -0.88],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_821d9bed4f56950d2f884c4c46559086 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_821d9bed4f56950d2f884c4c46559086.addTo(map_9bd689b2a0a68a3d6992c57177e6c76c);
#
#
#             var marker_3a6d2e8dd941f006e2713dcb2b882547 = L.marker(
#                 [41.64, -0.88],
#                 {
# }
#             ).addTo(map_9bd689b2a0a68a3d6992c57177e6c76c);
#
#
#         var popup_564549a62c263bdf6e0c92ad190095d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27030d3e8da1d2f85fa60284845764f3 = $(`&lt;div id=&quot;html_27030d3e8da1d2f85fa60284845764f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Zaragoza&lt;/div&gt;`)[0];
#                 popup_564549a62c263bdf6e0c92ad190095d7.setContent(html_27030d3e8da1d2f85fa60284845764f3);
#
#
#
#         marker_3a6d2e8dd941f006e2713dcb2b882547.bindPopup(popup_564549a62c263bdf6e0c92ad190095d7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # construir un mapa interactivo a partir de la tabla

# %%
mapa = folium.Map(location=[41.649693,-0.887712])

# %%
for indice, fila in accidentes.iterrows():
    marcador = folium.Marker([fila['lat'],fila['long']],\
                             popup=fila['type'])
    mapa.add_child(marcador)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_af55162d8349c403d3b22f661a031d65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_af55162d8349c403d3b22f661a031d65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_af55162d8349c403d3b22f661a031d65 = L.map(
#                 &quot;map_af55162d8349c403d3b22f661a031d65&quot;,
#                 {
#                     center: [41.649693, -0.887712],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ce92830d0db0df4e476b4c95b47c6f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ce92830d0db0df4e476b4c95b47c6f2.addTo(map_af55162d8349c403d3b22f661a031d65);
#
#
#             var marker_ed55def907427b5ead870f07d71a3d9b = L.marker(
#                 [41.66794268058468, -1.0108306797183846],
#                 {
# }
#             ).addTo(map_af55162d8349c403d3b22f661a031d65);
#
#
#         var popup_6b6d38965c6598b90d88934ec493c69e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63864ace506eaaf44e498bd6c7e12e90 = $(`&lt;div id=&quot;html_63864ace506eaaf44e498bd6c7e12e90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OTRAS&lt;/div&gt;`)[0];
#                 popup_6b6d38965c6598b90d88934ec493c69e.setContent(html_63864ace506eaaf44e498bd6c7e12e90);
#
#
#
#         marker_ed55def907427b5ead870f07d71a3d9b.bindPopup(popup_6b6d38965c6598b90d88934ec493c69e)
#         ;
#
#
#
#
#             var marker_a4ba9b117bd9e58ebaf78f5479e643ec = L.marker(
#                 [41.6543864004582, -0.8718366106168601],
#                 {
# }
#             ).addTo(map_af55162d8349c403d3b22f661a031d65);
#
#
#         var popup_99e670f11868435d0c737c5798b74644 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7a69c3640ca00adbe9533b9eaa9cc91 = $(`&lt;div id=&quot;html_a7a69c3640ca00adbe9533b9eaa9cc91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;COLISIÓN LATERAL&lt;/div&gt;`)[0];
#                 popup_99e670f11868435d0c737c5798b74644.setContent(html_a7a69c3640ca00adbe9533b9eaa9cc91);
#
#
#
#         marker_a4ba9b117bd9e58ebaf78f5479e643ec.bindPopup(popup_99e670f11868435d0c737c5798b74644)
#         ;
#
#
#
#
#             var marker_1371ed793ad7904918f9bf948ba3b53d = L.marker(
#                 [41.63868661503326, -0.9867478718241864],
#                 {
# }
#             ).addTo(map_af55162d8349c403d3b22f661a031d65);
#
#
#         var popup_c9a1d3b64ea8831072e85eb89e4303e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7e441e04e9128f9f9e47200ad252317 = $(`&lt;div id=&quot;html_d7e441e04e9128f9f9e47200ad252317&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;OTRAS&lt;/div&gt;`)[0];
#                 popup_c9a1d3b64ea8831072e85eb89e4303e3.setContent(html_d7e441e04e9128f9f9e47200ad252317);
#
#
#
#         marker_1371ed793ad7904918f9bf948ba3b53d.bindPopup(popup_c9a1d3b64ea8831072e85eb89e4303e3)
#         ;
#
#
#
#
#             var marker_c910e29db42647b09c851d3ddf5f9a12 = L.marker(
#                 [41.645231667155365, -0.8954535877671523],
#                 {
# }
#             ).addTo(map_af55162d8349c403d3b22f661a031d65);
#
#
#         var popup_c7efa393517d0d6ed176163d8bbf5e8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_482479b56891b04d4e5ad0c5b488c3b8 = $(`&lt;div id=&quot;html_482479b56891b04d4e5ad0c5b488c3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SALIDA CALZADA&lt;/div&gt;`)[0];
#                 popup_c7efa393517d0d6ed176163d8bbf5e8e.setContent(html_482479b56891b04d4e5ad0c5b488c3b8);
#
#
#
#         marker_c910e29db42647b09c851d3ddf5f9a12.bindPopup(popup_c7efa393517d0d6ed176163d8bbf5e8e)
#         ;
#
#
#
#
#             var marker_f6c82530ac27e8797fbf79daf9ad368f = L.marker(
#                 [41.65128399988019, -0.9191809206635221],
#                 {
# }
#             ).addTo(map_af55162d8349c403d3b22f661a031d65);
#
#
#         var popup_824736ab8b98fe7acc35f6709fa2c2c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f53695be1a916d0b82ef67b41d08f3b = $(`&lt;div id=&quot;html_1f53695be1a916d0b82ef67b41d08f3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;COLISIÓN LATERAL&lt;/div&gt;`)[0];
#                 popup_824736ab8b98fe7acc35f6709fa2c2c5.setConten

# %%
mapa.save("accidentes.html")

# %%
accidentes
# Out:
#                     type      long        lat
# 0                  OTRAS -1.010831  41.667943
# 1       COLISIÓN LATERAL -0.871837  41.654386
# 2                  OTRAS -0.986748  41.638687
# 3         SALIDA CALZADA -0.895454  41.645232
# 4       COLISIÓN LATERAL -0.919181  41.651284
# ..                   ...       ...        ...
# 195     COLISIÓN ALCANCE -0.908302  41.628050
# 196     COLISIÓN LATERAL -0.901875  41.664020
# 197     COLISIÓN LATERAL -0.926714  41.620191
# 198     COLISIÓN LATERAL -0.888658  41.673192
# 199  COLIS. MARCHA ATRÁS -0.889439  41.633478
#
# [200 rows x 3 columns]

# %%
for indice, fila in accidentes.iterrows():
# Out:
#   File "/tmp/ipykernel_17/1632637675.py", line 2
#
#     ^
# SyntaxError: incomplete input

# %%
m = folium.Map()

# %%
m

# %%
m = folium.Map(location=[41.649693,-0.887712], tiles="Stamen Terrain")

# %%
m

# %%
marcador = folium.Marker(location=[41.649693,-0.887712],icon=folium.Icon(color="red"))

# %%
m.add_child(marcador)

# %%
m.save("index.html")
